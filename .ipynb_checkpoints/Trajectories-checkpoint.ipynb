# %% [markdown]
# # Example

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]
z = [10, 9, 8, 7, 6]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Implementation

# %%
import json

# Load the JSON file
with open('my_project/controllers/my_controller/real_final_coords.json', 'r') as file:
    all_final_points = json.load(file)

# Verify the structure
#print(all_final_points)
for x in (all_final_points):
    print(f"Trajectory: {x}\n")
# Out:
# Trajectory: [[-0.0012, -0.1291, 0.2809], [0.195, -0.1552, 0.1371], [0.2043, -0.0516, 0.1006], [0.1873, -0.1153, 0.0266], [0.2012, -0.1716, 0.0924], [0.2023, -0.0781, 0.0597], [0.1993, -0.0998, 0.0438], [0.199, -0.1371, 0.0559], [0.1855, -0.087, 0.0793], [0.2026, -0.116, 0.0511], [0.2065, -0.1072, 0.0848], [0.2051, -0.1145, 0.0852]]
#
# Trajectory: [[0.1757, -0.0978, 0.1779], [0.1821, -0.078, 0.1497], [0.1982, -0.0452, 0.1281], [0.1856, -0.0985, 0.1434], [0.1671, -0.1707, 0.0229], [0.1782, -0.1508, 0.0333], [0.1893, -0.1261, 0.0063], [0.1863, -0.0841, 0.0997], [0.2043, -0.1153, 0.0769], [0.2024, -0.1002, 0.0598], [0.1799, -0.0931, 0.0556]]

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(all_final_points)):
    trajectory_to_plot= all_final_points[i]

    x = []
    y = []
    z = []

    for coordinate in trajectory_to_plot:
        x.append(coordinate[0])
        y.append(coordinate[1])
        z.append(coordinate[2])
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='r', marker='o')
    
    for index, (x_coord, y_coord, z_coord) in enumerate(trajectory_to_plot):
        ax.text(x_coord, y_coord, z_coord + 0.0001, str(index), color='blue')  # Adjust z + 0.1 to position text above the point


    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np

def is_decreasing(lst):
    return all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))

# Calcula la distancia euclidiana con respecto a la última coordenada en cada lista de `all_coordinates`
distances_to_last = []  # Lista para guardar las distancias

for coordinates in all_final_points:
    distances=[]
    for coord in coordinates:
        last_coord = np.array(coordinates[-1])  # Última coordenada en la lista actual
        distances.append(round(np.linalg.norm(np.array(coord) - last_coord),4))
        distances_to_last.append(distances)
        print(f"Coord: {coord}, distance to goal: {round(np.linalg.norm(np.array(coord) - last_coord),4)}")
    print(distances)
    if(is_decreasing(distances)):
        print("True, the trajectory is decreasing in distance at each point\n")
    else:
         print("False\n")

#print("Distances to last coordinate:", distances_to_last)
# Out:
# Coord: [-0.0012, -0.1291, 0.2809], distance to goal: 0.2847
# Coord: [0.195, -0.1552, 0.1371], distance to goal: 0.0667
# Coord: [0.2043, -0.0516, 0.1006], distance to goal: 0.0648
# Coord: [0.1873, -0.1153, 0.0266], distance to goal: 0.0612
# Coord: [0.2012, -0.1716, 0.0924], distance to goal: 0.0577
# Coord: [0.2023, -0.0781, 0.0597], distance to goal: 0.0445
# Coord: [0.1993, -0.0998, 0.0438], distance to goal: 0.0443
# Coord: [0.199, -0.1371, 0.0559], distance to goal: 0.0375
# Coord: [0.1855, -0.087, 0.0793], distance to goal: 0.0343
# Coord: [0.2026, -0.116, 0.0511], distance to goal: 0.0342
# Coord: [0.2065, -0.1072, 0.0848], distance to goal: 0.0074
# Coord: [0.2051, -0.1145, 0.0852], distance to goal: 0.0
# [0.2847, 0.0667, 0.0648, 0.0612, 0.0577, 0.0445, 0.0443, 0.0375, 0.0343, 0.0342, 0.0074, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1757, -0.0978, 0.1779], distance to goal: 0.1225
# Coord: [0.1821, -0.078, 0.1497], distance to goal: 0.0953
# Coord: [0.1982, -0.0452, 0.1281], distance to goal: 0.0888
# Coord: [0.1856, -0.0985, 0.1434], distance to goal: 0.0882
# Coord: [0.1671, -0.1707, 0.0229], distance to goal: 0.0852
# Coord: [0.1782, -0.1508, 0.0333], distance to goal: 0.0619
# Coord: [0.1893, -0.1261, 0.0063], distance to goal: 0.0601
# Coord: [0.1863, -0.0841, 0.0997], distance to goal: 0.0455
# Coord: [0.2043, -0.1153, 0.0769], distance to goal: 0.0393
# Coord: [0.2024, -0.1002, 0.0598], distance to goal: 0.024
# Coord: [0.1799, -0.0931, 0.0556], distance to goal: 0.0
# [0.1225, 0.0953, 0.0888, 0.0882, 0.0852, 0.0619, 0.0601, 0.0455, 0.0393, 0.024, 0.0]
# True, the trajectory is decreasing in distance at each point
