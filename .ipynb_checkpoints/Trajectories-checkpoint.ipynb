# %% [markdown]
# # Example

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]
z = [10, 9, 8, 7, 6]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Implementation

# %%
import json

# Load the JSON file
with open('my_project/controllers/my_controller/real_final_coords.json', 'r') as file:
    all_final_points = json.load(file)

# Verify the structure
#print(all_final_points)
for x in (all_final_points):
    print(f"Trajectory: {x}\n")
# Out:
# Trajectory: [[0.1864, -0.0456, 0.1826], [0.1551, -0.107, -0.0551], [0.1991, -0.0616, 0.1484], [0.1991, -0.0616, 0.1484], [0.1997, -0.1385, 0.0317], [0.1996, -0.1287, 0.0476], [0.2073, -0.1098, 0.0769], [0.2057, -0.1106, 0.0512], [0.1878, -0.082, 0.0793], [0.2099, -0.0761, 0.0812], [0.2043, -0.0727, 0.0597], [0.1965, -0.0462, 0.0523]]
#
# Trajectory: [[0.1164, -0.1958, -0.0638], [0.1891, -0.1434, 0.0044], [0.2057, -0.1106, 0.0511], [0.2039, -0.1832, 0.0634], [0.2099, -0.0761, 0.0812], [0.2056, -0.0461, 0.1006], [0.1794, -0.2138, 0.1288], [0.2027, -0.0527, 0.1526], [0.1747, -0.0633, 0.2078], [0.146, -0.164, 0.212], [0.1456, -0.1207, 0.258], [0.1243, -0.1328, 0.2432]]
#
# ...

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(all_final_points)):
    trajectory_to_plot= all_final_points[i]

    x = []
    y = []
    z = []

    for coordinate in trajectory_to_plot:
        x.append(coordinate[0])
        y.append(coordinate[1])
        z.append(coordinate[2])
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='r', marker='o')
    
    for index, (x_coord, y_coord, z_coord) in enumerate(trajectory_to_plot):
        ax.text(x_coord, y_coord, z_coord + 0.0001, str(index), color='blue')  # Adjust z + 0.1 to position text above the point


    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt

def is_decreasing(lst):
    return all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))

# Calcula la distancia euclidiana con respecto a la última coordenada en cada lista de `all_final_points`
distances_to_last = []  # Lista para guardar las distancias

for coordinates in all_final_points:
    distances = []
    for coord in coordinates:
        last_coord = np.array(coordinates[-1])  # Última coordenada en la lista actual
        dist = round(np.linalg.norm(np.array(coord) - last_coord), 4)
        distances.append(dist)
        print(f"Coord: {coord}, distance to goal: {dist}")
    distances_to_last.append(distances)  # Guardamos la lista de distancias
    print(distances)
    if is_decreasing(distances):
        print("True, the trajectory is decreasing in distance at each point\n")
    else:
        print("False\n")

# Graficamos las distancias
plt.figure(figsize=(10, 6))
for i, distances in enumerate(distances_to_last):
    plt.plot(distances, label=f'Trajectory {i+1}')
plt.xlabel('Step')
plt.ylabel('Distance to Last Coordinate')
plt.title('Distance to Last Coordinate over Time for Each Learnt Trajectory')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coord: [0.1864, -0.0456, 0.1826], distance to goal: 0.1307
# Coord: [0.1551, -0.107, -0.0551], distance to goal: 0.1302
# Coord: [0.1991, -0.0616, 0.1484], distance to goal: 0.0974
# Coord: [0.1991, -0.0616, 0.1484], distance to goal: 0.0974
# Coord: [0.1997, -0.1385, 0.0317], distance to goal: 0.0946
# Coord: [0.1996, -0.1287, 0.0476], distance to goal: 0.0827
# Coord: [0.2073, -0.1098, 0.0769], distance to goal: 0.069
# Coord: [0.2057, -0.1106, 0.0512], distance to goal: 0.0651
# Coord: [0.1878, -0.082, 0.0793], distance to goal: 0.0457
# Coord: [0.2099, -0.0761, 0.0812], distance to goal: 0.0437
# Coord: [0.2043, -0.0727, 0.0597], distance to goal: 0.0286
# Coord: [0.1965, -0.0462, 0.0523], distance to goal: 0.0
# [0.1307, 0.1302, 0.0974, 0.0974, 0.0946, 0.0827, 0.069, 0.0651, 0.0457, 0.0437, 0.0286, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1164, -0.1958, -0.0638], distance to goal: 0.3135
# ...
