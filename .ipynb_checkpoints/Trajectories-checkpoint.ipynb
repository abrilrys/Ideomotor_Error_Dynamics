# %% [markdown]
# # Example

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]
z = [10, 9, 8, 7, 6]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Implementation

# %%
import json

# Load the JSON file
with open('my_project/controllers/my_controller/real_final_coords.json', 'r') as file:
    all_final_points = json.load(file)

# Verify the structure
#print(all_final_points)
for x in (all_final_points):
    print(f"Trajectory: {x}\n")
# Out:
# Trajectory: [[0.2077, -0.1067, 0.0512], [0.1884, -0.1432, 0.2128], [0.2094, -0.1058, 0.0769], [0.2019, -0.144, 0.1787], [0.2039, -0.1544, 0.1731], [0.2102, -0.0987, 0.1628], [0.2102, -0.0987, 0.1628], [0.2102, -0.0987, 0.1628], [0.2102, -0.0987, 0.1628], [0.2005, -0.151, 0.1107], [0.2033, -0.1489, 0.1251], [0.2071, -0.1282, 0.1367]]
#
# Trajectory: [[0.1512, -0.1689, -0.0363], [0.1902, -0.1884, 0.0664], [0.1682, -0.127, 0.2406], [0.2081, -0.1051, 0.0753], [0.2113, -0.0721, 0.0812], [0.2113, -0.0721, 0.0812], [0.1893, -0.0785, 0.0793], [0.1873, -0.0421, 0.1826], [0.2089, -0.1245, 0.1569], [0.2143, -0.0811, 0.1279], [0.1885, -0.0707, 0.1258], [0.1899, -0.0899, 0.1434]]
#
# Trajectory: [[0.1723, -0.2087, 0.1827], [0.2019, -0.1461, 0.137], [0.2049, -0.1562, 0.1454], [0.18, -0.0897, 0.1779], [0.2039, -0.1544, 0.1731], [0.2039, -0.1544, 0.1731], [0.1848, -0.1783, 0.2039], [0.1816, -0.1023, 0.2228], [0.1884, -0.1432, 0.2128], [0.1884, -0.1432, 0.2128], [0.1904, -0.1359, 0.2102], [0.1904, -0.1359, 0.2102]]
#
# Trajectory: [[0.1429, -0.0721, 0.223], [0.1563, -0.0788, 0.212], [0.2018, -0.1441, 0.1787], [0.2084, -0.1725, 0.1485], [0.2001, -0.0361, 0.1281], [0.1893, -0.0785, 0.0793], [0.2077, -0.1066, 0.0511], [0.1002, -0.1274, -0.0745], [0.0983, -0.1086, -0.0776], [0.1097, -0.1007, -0.0695], [0.124, -0.0735, -0.0547], [0.1424, -0.042, -0.0337]]
#
# Trajectory: [[0.2064, -0.0422, 0.1006], [0.1792, -0.098, 0.0374], [0.1948, -0.0948, 0.0128], [0.1949, -0.1173, 0.0063], [0.1949, -0.1173, 0.0063], [0.1949, -0.1173, 0.0063], [0.1423, -0.1461, -0.0652], [0.1627, -0.0529, -0.0176], [0.1821, -0.0801, -0.0066], [0.1821, -0.0801, -0.0066], [0.1815, -0.0943, -0.0128], [0.1644, -0.0996, -0.0418]]
#
# Trajectory: [[0.1229, -0.1002, 0.2745], [0.2089, -0.1245, 0.1569], [0.2001, -0.0361, 0.1281], [0.1885, -0.0707, 0.1258], [0.1621, -0.1041, 0.2082], [0.2036, -0.0488, 0.1526], [0.2002, -0.0578, 0.1485], [0.1563, -0.0788, 0.212], [0.1854, -0.0695, 0.1497], [0.1782, -0.0844, 0.1753], [0.1776, -0.0643, 0.1692], [0.1749, -0.0683, 0.1824]]
#
# Trajectory: [[0.1839, -0.0848, 0.0556], [0.199, -0.1255, 0.0433], [0.1849, -0.1424, 0.0333], [0.2143, -0.0811, 0.1279], [0.2063, -0.1528, 0.0596], [0.1782, -0.0844, 0.1753], [0.1358, -0.0996, 0.2384], [0.18, -0.0896, 0.1779], [0.2089, -0.1245, 0.157], [0.2018, -0.1441, 0.1787], [0.159, -0.195, 0.2195], [0.1507, -0.233, 0.1779]]

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(all_final_points)):
    trajectory_to_plot= all_final_points[i]

    x = []
    y = []
    z = []

    for coordinate in trajectory_to_plot:
        x.append(coordinate[0])
        y.append(coordinate[1])
        z.append(coordinate[2])
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='r', marker='o')
    
    for index, (x_coord, y_coord, z_coord) in enumerate(trajectory_to_plot):
        ax.text(x_coord, y_coord, z_coord + 0.0001, str(index), color='blue')  # Adjust z + 0.1 to position text above the point


    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt

def is_decreasing(lst):
    return all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))

# Calcula la distancia euclidiana con respecto a la última coordenada en cada lista de `all_final_points`
distances_to_last = []  # Lista para guardar las distancias

for coordinates in all_final_points:
    distances = []
    for coord in coordinates:
        last_coord = np.array(coordinates[-1])  # Última coordenada en la lista actual
        dist = round(np.linalg.norm(np.array(coord) - last_coord), 4)
        distances.append(dist)
        print(f"Coord: {coord}, distance to goal: {dist}")
    distances_to_last.append(distances)  # Guardamos la lista de distancias
    print(distances)
    if is_decreasing(distances):
        print("True, the trajectory is decreasing in distance at each point\n")
    else:
        print("False\n")

# Graficamos las distancias
plt.figure(figsize=(10, 6))
for i, distances in enumerate(distances_to_last):
    plt.plot(distances, label=f'Trajectory {i+1}')
plt.xlabel('Step')
plt.ylabel('Distance to Last Coordinate')
plt.title('Distance to Last Coordinate over Time for Each Learnt Trajectory')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coord: [0.2077, -0.1067, 0.0512], distance to goal: 0.0882
# Coord: [0.1884, -0.1432, 0.2128], distance to goal: 0.0798
# Coord: [0.2094, -0.1058, 0.0769], distance to goal: 0.0639
# Coord: [0.2019, -0.144, 0.1787], distance to goal: 0.0452
# Coord: [0.2039, -0.1544, 0.1731], distance to goal: 0.045
# Coord: [0.2102, -0.0987, 0.1628], distance to goal: 0.0395
# Coord: [0.2102, -0.0987, 0.1628], distance to goal: 0.0395
# Coord: [0.2102, -0.0987, 0.1628], distance to goal: 0.0395
# Coord: [0.2102, -0.0987, 0.1628], distance to goal: 0.0395
# Coord: [0.2005, -0.151, 0.1107], distance to goal: 0.0352
# Coord: [0.2033, -0.1489, 0.1251], distance to goal: 0.024
# Coord: [0.2071, -0.1282, 0.1367], distance to goal: 0.0
# [0.0882, 0.0798, 0.0639, 0.0452, 0.045, 0.0395, 0.0395, 0.0395, 0.0395, 0.0352, 0.024, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1512, -0.1689, -0.0363], distance to goal: 0.2001
# Coord: [0.1902, -0.1884, 0.0664], distance to goal: 0.125
# Coord: [0.1682, -0.127, 0.2406], distance to goal: 0.1063
# Coord: [0.2081, -0.1051, 0.0753], distance to goal: 0.0721
# Coord: [0.2113, -0.0721, 0.0812], distance to goal: 0.0681
# Coord: [0.2113, -0.0721, 0.0812], distance to goal: 0.0681
# Coord: [0.1893, -0.0785, 0.0793], distance to goal: 0.0651
# Coord: [0.1873, -0.0421, 0.1826], distance to goal: 0.0619
# Coord: [0.2089, -0.1245, 0.1569], distance to goal: 0.0417
# Coord: [0.2143, -0.0811, 0.1279], distance to goal: 0.0302
# Coord: [0.1885, -0.0707, 0.1258], distance to goal: 0.0261
# Coord: [0.1899, -0.0899, 0.1434], distance to goal: 0.0
# [0.2001, 0.125, 0.1063, 0.0721, 0.0681, 0.0681, 0.0651, 0.0619, 0.0417, 0.0302, 0.0261, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1723, -0.2087, 0.1827], distance to goal: 0.0799
# Coord: [0.2019, -0.1461, 0.137], distance to goal: 0.0748
# Coord: [0.2049, -0.1562, 0.1454], distance to goal: 0.0694
# Coord: [0.18, -0.0897, 0.1779], distance to goal: 0.0573
# Coord: [0.2039, -0.1544, 0.1731], distance to goal: 0.0436
# Coord: [0.2039, -0.1544, 0.1731], distance to goal: 0.0436
# Coord: [0.1848, -0.1783, 0.2039], distance to goal: 0.0432
# Coord: [0.1816, -0.1023, 0.2228], distance to goal: 0.0369
# Coord: [0.1884, -0.1432, 0.2128], distance to goal: 0.008
# Coord: [0.1884, -0.1432, 0.2128], distance to goal: 0.008
# Coord: [0.1904, -0.1359, 0.2102], distance to goal: 0.0
# Coord: [0.1904, -0.1359, 0.2102], distance to goal: 0.0
# [0.0799, 0.0748, 0.0694, 0.0573, 0.0436, 0.0436, 0.0432, 0.0369, 0.008, 0.008, 0.0, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1429, -0.0721, 0.223], distance to goal: 0.2585
# Coord: [0.1563, -0.0788, 0.212], distance to goal: 0.2488
# Coord: [0.2018, -0.1441, 0.1787], distance to goal: 0.243
# Coord: [0.2084, -0.1725, 0.1485], distance to goal: 0.2336
# Coord: [0.2001, -0.0361, 0.1281], distance to goal: 0.1719
# Coord: [0.1893, -0.0785, 0.0793], distance to goal: 0.1277
# Coord: [0.2077, -0.1066, 0.0511], distance to goal: 0.125
# Coord: [0.1002, -0.1274, -0.0745], distance to goal: 0.1036
# Coord: [0.0983, -0.1086, -0.0776], distance to goal: 0.0911
# Coord: [0.1097, -0.1007, -0.0695], distance to goal: 0.0761
# Coord: [0.124, -0.0735, -0.0547], distance to goal: 0.0421
# Coord: [0.1424, -0.042, -0.0337], distance to goal: 0.0
# [0.2585, 0.2488, 0.243, 0.2336, 0.1719, 0.1277, 0.125, 0.1036, 0.0911, 0.0761, 0.0421, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.2064, -0.0422, 0.1006], distance to goal: 0.1592
# Coord: [0.1792, -0.098, 0.0374], distance to goal: 0.0806
# Coord: [0.1948, -0.0948, 0.0128], distance to goal: 0.0627
# Coord: [0.1949, -0.1173, 0.0063], distance to goal: 0.0596
# Coord: [0.1949, -0.1173, 0.0063], distance to goal: 0.0596
# Coord: [0.1949, -0.1173, 0.0063], distance to goal: 0.0596
# Coord: [0.1423, -0.1461, -0.0652], distance to goal: 0.0566
# Coord: [0.1627, -0.0529, -0.0176], distance to goal: 0.0526
# Coord: [0.1821, -0.0801, -0.0066], distance to goal: 0.044
# Coord: [0.1821, -0.0801, -0.0066], distance to goal: 0.044
# Coord: [0.1815, -0.0943, -0.0128], distance to goal: 0.0341
# Coord: [0.1644, -0.0996, -0.0418], distance to goal: 0.0
# [0.1592, 0.0806, 0.0627, 0.0596, 0.0596, 0.0596, 0.0566, 0.0526, 0.044, 0.044, 0.0341, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1229, -0.1002, 0.2745], distance to goal: 0.1105
# Coord: [0.2089, -0.1245, 0.1569], distance to goal: 0.0705
# Coord: [0.2001, -0.0361, 0.1281], distance to goal: 0.068
# Coord: [0.1885, -0.0707, 0.1258], distance to goal: 0.0583
# Coord: [0.1621, -0.1041, 0.2082], distance to goal: 0.0459
# Coord: [0.2036, -0.0488, 0.1526], distance to goal: 0.0457
# Coord: [0.2002, -0.0578, 0.1485], distance to goal: 0.0436
# Coord: [0.1563, -0.0788, 0.212], distance to goal: 0.0365
# Coord: [0.1854, -0.0695, 0.1497], distance to goal: 0.0344
# Coord: [0.1782, -0.0844, 0.1753], distance to goal: 0.0179
# Coord: [0.1776, -0.0643, 0.1692], distance to goal: 0.0141
# Coord: [0.1749, -0.0683, 0.1824], distance to goal: 0.0
# [0.1105, 0.0705, 0.068, 0.0583, 0.0459, 0.0457, 0.0436, 0.0365, 0.0344, 0.0179, 0.0141, 0.0]
# True, the trajectory is decreasing in distance at each point
#
# Coord: [0.1839, -0.0848, 0.0556], distance to goal: 0.195
# Coord: [0.199, -0.1255, 0.0433], distance to goal: 0.1789
# Coord: [0.1849, -0.1424, 0.0333], distance to goal: 0.174
# Coord: [0.2143, -0.0811, 0.1279], distance to goal: 0.1721
# Coord: [0.2063, -0.1528, 0.0596], distance to goal: 0.1534
# Coord: [0.1782, -0.0844, 0.1753], distance to goal: 0.1511
# Coord: [0.1358, -0.0996, 0.2384], distance to goal: 0.1472
# Coord: [0.18, -0.0896, 0.1779], distance to goal: 0.1464
# Coord: [0.2089, -0.1245, 0.157], distance to goal: 0.1249
# Coord: [0.2018, -0.1441, 0.1787], distance to goal: 0.1025
# Coord: [0.159, -0.195, 0.2195], distance to goal: 0.057
# Coord: [0.1507, -0.233, 0.1779], distance to goal: 0.0
# [0.195, 0.1789, 0.174, 0.1721, 0.1534, 0.1511, 0.1472, 0.1464, 0.1249, 0.1025, 0.057, 0.0]
# True, the trajectory is decreasing in distance at each point
# <img src="data:image/png;base64,..." width="1000">
